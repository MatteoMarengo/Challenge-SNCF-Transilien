# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from prophet import Prophet

# %%
# Load the data
x_train = pd.read_csv('../data-challenge/x_train_sncf.csv')
x_test = pd.read_csv('../data-challenge/x_test_sncf.csv')
y_train = pd.read_csv('../data-challenge/y_train_sncf.csv')

# x_train = pd.read_csv('/kaggle/input/sncf-prediction-train-2015-2022/x_train_sncf.csv')
# x_test = pd.read_csv('/kaggle/input/sncf-prediction-train-2015-2022/x_test_sncf.csv')
# y_train = pd.read_csv('/kaggle/input/sncf-prediction-train-2015-2022/y_train_sncf.csv')

# %%
# add the index column on x_train
x_train['index'] = x_train['date'].str.cat(x_train['station'], sep='_')
x_train.head()
# Out:
#          date station  job  ferie  vacances           index
# 0  2015-01-01     1J7    1      1         1  2015-01-01_1J7
# 1  2015-01-01     O2O    1      1         1  2015-01-01_O2O
# 2  2015-01-01     8QR    1      1         1  2015-01-01_8QR
# 3  2015-01-01     UMC    1      1         1  2015-01-01_UMC
# 4  2015-01-01     FK3    1      1         1  2015-01-01_FK3

# %%
# merge x_train and y_train on index
data_train = pd.merge(x_train, y_train, on='index')
data_train = data_train[['date', 'station', 'index', 'job', 'ferie', 'vacances', 'y']]
data_train['train'] = 1

data_train.head()
# Out:
#          date station           index  job  ferie  vacances   y  train
# 0  2015-01-01     1J7  2015-01-01_1J7    1      1         1   7      1
# 1  2015-01-01     O2O  2015-01-01_O2O    1      1         1   0      1
# 2  2015-01-01     8QR  2015-01-01_8QR    1      1         1   9      1
# 3  2015-01-01     UMC  2015-01-01_UMC    1      1         1   9      1
# 4  2015-01-01     FK3  2015-01-01_FK3    1      1         1  28      1

# %%
# merge the above data with x_test
x_test['train'] = 0
merged_data = pd.concat([data_train, x_test], ignore_index=True).sort_values(by=['date'])
merged_data['y'] = merged_data['y'].fillna(0)

merged_data.tail()
# Out:
#                date station           index  job  ferie  vacances    y  train
# 1307138  2023-06-30     4AH  2023-06-30_4AH    1      0         0  0.0      0
# 1307139  2023-06-30     8XN  2023-06-30_8XN    1      0         0  0.0      0
# 1307140  2023-06-30     ESA  2023-06-30_ESA    1      0         0  0.0      0
# 1307129  2023-06-30     X6B  2023-06-30_X6B    1      0         0  0.0      0
# 1306842  2023-06-30     HW6  2023-06-30_HW6    1      0         0  0.0      0

# %%
stations = merged_data['station'].unique()
stations
# Out:
# array(['1J7', 'S3E', 'RDK', 'I9U', 'OM7', '09U', '0S9', 'KO0', '4WI',
#        '23N', 'WVV', 'SWS', 'TFW', 'X3T', 'I8D', 'EOE', 'MBC', 'VS0',
#        'EVR', 'BZL', 'DF2', 'APM', '12Q', 'L6F', 'WDP', 'ZII', 'W67',
#        '4V8', '214', '2YA', 'L15', 'PRZ', '2UV', 'OF0', 'PCE', 'UAJ',
#        'K75', '9RF', '2EW', '6E0', '033', 'KHT', 'P8U', 'CW1', 'AK3',
#        'IJR', 'CM6', 'NZP', 'ICH', 'Q62', '19G', 'CS1', 'T2H', 'TMT',
#        'DRI', 'KAX', 'BC6', '6VM', 'UCE', '0CM', 'V5L', 'BI7', 'Q5M',
#        '1EB', 'IAM', 'AOW', 'YX9', '7EJ', '0WC', 'WQR', 'WQO', 'LHY',
#        '193', 'PQF', 'XN6', '0YY', '1VL', '1AA', 'A1R', '9P6', '6HE',
#        '700', 'SZ5', 'H2M', 'SSM', 'G1F', 'QTM', 'K6N', 'N6O', 'HZ1',
#        'ZIK', '294', 'Y1C', 'BUH', 'XM1', '0GU', 'B34', 'NXN', '9MC',
#        'JFA', 'AGN', 'I6E', 'W68', 'VZD', 'V6N', '5SM', 'UM6', '4RW',
#        'MPO', 'MX8', 'MBB', 'FTX', 'PD6', 'T16', 'I10', 'WNT', '4EG',
#        'X2X', 'HN1', 'ARC', 'T5V', 'K2M', 'V2R', 'OE1', '94K', 'C5E',
#        'VTE', '2T1', '0JU', 'X3Q', 'RVB', '488', 'DS2', '4CZ', '9LN',
#        '6FB', 'XXI', '959', '2SG', 'CQT', 'B5A', 'YAQ', 'RPX', 'VTP',
#        '4MO', '034', 'BJ5', 'KBV', 'J52', '2AC', '56W', 'T29', 'PEA',
#        'BL1', 'YJK', '92P', 'NEG', '3T2', 'N6I', 'QL3', 'M36', 'X6B',
#        'O5P', 'CET', 'E6L', 'P7I', '9IV', '0ZP', '52H', 'PWO', '6TL',
#        'X95', 'NSN', 'GIE', 'IJC', 'BJM', 'TV1', 'AZV', 'TCL', 'VEO',
#        'WO7', 'WMZ', '3Y4', 'OQD', 'UC4', 'GMD', 'Z76', 'VBL', 'VMM',
#        'BE1', 'TGW', 'W06', 'GUQ', 'ANI', 'TO8', 'I7J', '26J', 'REW',
#        'K4X', 'XL2', 'H2L', 'I8O', 'HXV', 'ESA', '8XN', '4AH', 'ZSR',
#        'KEC', 'PUW', '0TR', 'B8A', 'KY2', 'Q70', '4YU', 'N7J', '9WY',
#        'HOX', 'B3W', 'VGQ', 'BNR', '3KU', 'V4D', 'EBP', 'JD3', '34L',
#        'MK9', '5S5', 'BZ0', '59A', '4IM', 'CWQ', '30I', 'HW6', 'JX6',
#        'F77', 'JCW', 'FBH', 'P4J', 'QV8', 'J9O', '5WG', '5PK', '4PO',
#        '72S', 'XOK', 'GKH', 'BPW', '5U5', 'CJP', 'NVE', 'T91', 'BKJ',
#        'XRB', '289', '87K', 'EIZ', '3W6', 'HOC', '651', '3NQ', 'DBV',
#        'SH9', 'QQJ', '5GK', 'FYB', '8WZ', '6WR', '5KB', 'MNO', 'GV0',
#        'VML', 'EPD', 'FA8', 'I9K', '4UY', 'CUF', 'TEP', 'RYX', 'O7B',
#        '357', 'EK4', 'V8D', 'KY6', 'I1K', 'FK3', 'UMC', '8QR', 'O2O',
#        'VVQ', 'BRZ', '6DU', 'BUY', '276', 'VI4', 'J9C', 'IOR', 'NT4',
#        'MM6', 'G10', 'JCN', 'OOY', '30R', 'CSD', 'XIG', 'R83', '8X9',
#        'GOJ', 'Z2T', 'YTV', 'OD3', 'JXV', 'XTG', 'RR1', '6UW', '1PW',
#        'IFB', 'C3A', 'MIH', 'E9M', 'DSX', 'XKD', 'W7F', '45E', 'BHE',
#        'A8Q', 'DMX', 'B45', '0Y9', '182', 'SAD', 'TVC', '1EX', 'FKG',
#        '856', 'Y5A', 'KN2', 'J4R', 'YLE', 'BRP', 'SYW', '003', 'EMR',
#        'VA1', 'FSR', 'ZXY', '3XF', 'H5M', '6A9', '969', 'TGR', 'NWM',
#        'PBR', 'RM4', 'AOH', '8PU', 'GTH', 'R2F', 'TXU', 'WDG', 'C4L',
#        'MDL', 'KA0', 'VTD', 'EHY', '43B', 'HID', '495', '47F', 'VEF',
#        '5KJ', 'YDH', '9IN', 'Z1H', 'OUG', 'F30', 'TPX', 'WIX', '56P',
#        'Z5T', 'XUL', '25G', 'OTS', '3NS', '4SH', '11W', 'GN3', 'CYD',
#        '1TE', '222', '7NG', '8E0', 'B61', 'B3D', 'P3G', 'OYD', 'KDO',
#        'APN', 'WRR', 'F7I', 'D68', 'K5Q', 'WGP', 'K71', 'FBN', '745',
#        '1TQ', 'VAU', '5MR', '5ZC', 'CRS', 'Z4A', '18L', '2PZ', 'JP8',
#        '1I8', '2P1', 'B9M', 'H1M', '1EJ', 'ROF', 'EFN', 'B65', 'KQC',
#        'VV4', 'NZV', 'L58', 'EQX', 'NEB', 'RF2', 'GW7', 'OWM', 'V2P',
#        'N9K', '48S', 'P6E', 'BDC', 'W14', 'W80', 'QD6'], dtype=object)

# %%
df_per_station = {station: merged_data[merged_data['station'] == station].sort_values(by='date')[["date", "job", "ferie", "vacances", "y", "train"]] for station in stations}

# %%
df_per_station['O2O'].head()
# Out:
#               date  job  ferie  vacances     y  train
# 1       2015-01-01    1      1         1   0.0      1
# 40303   2015-01-02    1      0         1   8.0      1
# 80892   2015-01-03    0      0         1   0.0      1
# 121380  2015-01-04    0      0         1   0.0      1
# 161890  2015-01-05    1      0         0  27.0      1

# %%
print(list(df_per_station['O2O']['y']))
# Out:
# [0.0, 8.0, 0.0, 0.0, 27.0, 35.0, 21.0, 31.0, 27.0, 0.0, 0.0, 24.0, 22.0, 20.0, 24.0, 24.0, 0.0, 5.0, 24.0, 22.0, 27.0, 25.0, 21.0, 6.0, 0.0, 22.0, 22.0, 24.0, 22.0, 23.0, 0.0, 0.0, 27.0, 33.0, 20.0, 25.0, 23.0, 8.0, 31.0, 23.0, 20.0, 21.0, 22.0, 16.0, 0.0, 12.0, 25.0, 25.0, 15.0, 20.0, 19.0, 0.0, 6.0, 14.0, 11.0, 18.0, 16.0, 19.0, 0.0, 7.0, 24.0, 24.0, 20.0, 26.0, 20.0, 6.0, 13.0, 22.0, 19.0, 21.0, 21.0, 22.0, 0.0, 14.0, 25.0, 28.0, 15.0, 19.0, 18.0, 7.0, 5.0, 23.0, 24.0, 19.0, 20.0, 18.0, 0.0, 9.0, 23.0, 27.0, 19.0, 19.0, 17.0, 0.0, 14.0, 19.0, 22.0, 22.0, 18.0, 22.0, 5.0, 0.0, 23.0, 25.0, 22.0, 29.0, 17.0, 0.0, 5.0, 20.0, 21.0, 17.0, 21.0, 16.0, 0.0, 0.0, 22.0, 22.0, 16.0, 18.0, 0.0, 0.0, 15.0, 26.0, 27.0, 24.0, 21.0, 0.0, 6.0, 0.0, 26.0, 19.0, 15.0, 0.0, 6.0, 0.0, 6.0, 20.0, 15.0, 19.0, 23.0, 24.0, 6.0, 0.0, 5.0, 22.0, 19.0, 21.0, 20.0, 0.0, 15.0, 18.0, 20.0, 16.0, 19.0, 14.0, 0.0, 0.0, 20.0, 21.0, 16.0, 22.0, 21.0, 0.0, 37.0, 21.0, 21.0, 5.0, 17.0, 7.0, 12.0, 19.0, 14.0, 12.0, 18.0, 16.0, 6.0, 5.0, 14.0, 12.0, 19.0, 16.0, 21.0, 0.0, 7.0, 10.0, 16.0, 11.0, 12.0, 18.0, 0.0, 10.0, 18.0, 12.0, 14.0, 15.0, 11.0, 0.0, 7.0, 13.0, 14.0, 8.0, 11.0, 12.0, 0.0, 8.0, 7.0, 9.0, 10.0, 12.0, 5.0, 0.0, 0.0, 13.0, 10.0, 12.0, 15.0, 11.0, 0.0, 0.0, 12.0, 10.0, 9.0, 9.0, 13.0, 6.0, 9.0, 13.0, 23.0, 23.0, 31.0, 20.0, 0.0, 9.0, 25.0, 25.0, 25.0, 31.0, 7.0, 0.0, 5.0, 33.0, 31.0, 27.0, 30.0, 22.0, 10.0, 0.0, 29.0, 27.0, 23.0, 27.0, 23.0, 7.0, 13.0, 31.0, 31.0, 29.0, 23.0, 30.0, 5.0, 5.0, 31.0, 29.0, 20.0, 22.0, 22.0, 6.0, 0.0, 26.0, 29.0, 24.0, 34.0, 20.0, 0.0, 31.0, 27.0, 14.0, 16.0, 20.0, 26.0, 0.0, 7.0, 28.0, 17.0, 16.0, 29.0, 17.0, 5.0, 13.0, 35.0, 38.0, 28.0, 31.0, 26.0, 0.0, 11.0, 31.0, 28.0, 0.0, 31.0, 14.0, 5.0, 0.0, 27.0, 30.0, 26.0, 28.0, 24.0, 0.0, 9.0, 29.0, 24.0, 22.0, 23.0, 21.0, 0.0, 16.0, 27.0, 15.0, 25.0, 23.0, 28.0, 6.0, 7.0, 43.0, 28.0, 21.0, 25.0, 23.0, 0.0, 0.0, 26.0, 25.0, 26.0, 31.0, 25.0, 0.0, 0.0, 16.0, 20.0, 11.0, 9.0, 5.0, 11.0, 5.0, 11.0, 7.0, 9.0, 8.0, 0.0, 6.0, 0.0, 31.0, 30.0, 23.0, 25.0, 30.0, 8.0, 6.0, 32.0, 30.0, 28.0, 29.0, 24.0, 6.0, 0.0, 31.0, 30.0, 25.0, 23.0, 0.0, 0.0, 0.0, 21.0, 25.0, 27.0, 31.0, 18.0, 6.0, 6.0, 33.0, 36.0, 28.0, 30.0, 19.0, 0.0, 0.0, 36.0, 31.0, 30.0, 29.0, 30.0, 0.0, 0.0, 38.0, 37.0, 35.0, 34.0, 26.0, 10.0, 7.0, 34.0, 28.0, 24.0, 37.0, 27.0, 6.0, 7.0, 29.0, 24.0, 30.0, 19.0, 17.0, 7.0, 29.0, 35.0, 27.0, 5.0, 27.0, 33.0, 0.0, 13.0, 34.0, 33.0, 23.0, 30.0, 24.0, 5.0, 21.0, 34.0, 42.0, 35.0, 33.0, 26.0, 6.0, 14.0, 17.0, 27.0, 26.0, 10.0, 19.0, 7.0, 0.0, 32.0, 34.0, 34.0, 53.0, 30.0, 12.0, 30.0, 36.0, 36.0, 29.0, 32.0, 30.0, 12.0, 13.0, 27.0, 25.0, 37.0, 20.0, 19.0, 0.0, 20.0, 27.0, 9.0, 18.0, 21.0, 17.0, 5.0, 8.0, 30.0, 30.0, 26.0, 0.0, 15.0, 9.0, 24.0, 37.0, 33.0, 29.0, 23.0, 30.0, 16.0, 6.0, 12.0, 25.0, 25.0, 16.0, 24.0, 5.0, 20.0, 28.0, 35.0, 26.0, 27.0, 26.0, 11.0, 15.0, 36.0, 18.0, 7.0, 0.0, 0.0, 10.0, 10.0, 12.0, 12.0, 7.0, 0.0, 0.0, 19.0, 13.0, 21.0, 17.0, 18.0, 5.0, 37.0, 18.0, 34.0, 21.0, 19.0, 15.0, 5.0, 6.0, 18.0, 27.0, 14.0, 16.0, 21.0, 0.0, 7.0, 12.0, 19.0, 15.0, 25.0, 22.0, 0.0, 7.0, 14.0, 21.0, 20.0, 0.0, 14.0, 0.0, 10.0, 28.0, 28.0, 19.0, 22.0, 14.0, 0.0, 13.0, 31.0, 23.0, 17.0, 17.0, 22.0, 11.0, 5.0, 20.0, 26.0, 16.0, 18.0, 25.0, 11.0, 18.0, 14.0, 18.0, 14.0, 16.0, 13.0, 6.0, 8.0, 0.0, 8.0, 9.0, 9.0, 13.0, 6.0, 16.0, 12.0, 18.0, 12.0, 16.0, 12.0, 0.0, 12.0, 22.0, 0.0, 13.0, 12.0, 19.0, 10.0, 26.0, 29.0, 27.0, 24.0, 35.0, 33.0, 0.0, 11.0, 34.0, 27.0, 19.0, 28.0, 31.0, 0.0, 7.0, 32.0, 32.0, 22.0, 33.0, 29.0, 5.0, 11.0, 34.0, 32.0, 29.0, 37.0, 24.0, 5.0, 9.0, 36.0, 33.0, 30.0, 35.0, 27.0, 0.0, 9.0, 35.0, 34.0, 25.0, 29.0, 23.0, 7.0, 10.0, 30.0, 29.0, 25.0, 26.0, 25.0, 5.0, 0.0, 15.0, 21.0, 13.0, 14.0, 15.0, 0.0, 5.0, 28.0, 7.0, 14.0, 40.0, 41.0, 0.0, 9.0, 34.0, 30.0, 21.0, 35.0, 0.0, 10.0, 9.0, 33.0, 34.0, 30.0, 29.0, 30.0, 10.0, 5.0, 27.0, 35.0, 20.0, 28.0, 32.0, 0.0, 0.0, 31.0, 31.0, 31.0, 27.0, 28.0, 0.0, 197.0, 33.0, 31.0, 16.0, 20.0, 21.0, 8.0, 12.0, 41.0, 37.0, 28.0, 39. ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(np.array(df_per_station['CQT'][df_per_station['CQT']['train'] == 1]['y']))
plt.xlabel('Time (days)')
plt.ylabel('Validations')
plt.title('Validations over time for station O2O')
plt.show()

# %%
def mean_absolute_percentage_error(y_true, y_pred, eps=1e-5):
    return np.mean(np.abs((y_true - y_pred) / (y_true + eps))) * 100

# %%
# Create an empty y_test dataframe
y_test = pd.DataFrame()
# Convert 'date' column to string type
x_test['date'] = x_test['date'].astype(str)
# First column name is 'index'
y_test['index'] = x_test['date'].str.cat(x_test['station'], sep='_')
# Second column name is 'y'
y_test['y'] = 0

print(y_test.head())
# Out:
#             index  y
# 0  2023-01-01_1J7  0
# 1  2023-01-01_O2O  0
# 2  2023-01-01_8QR  0
# 3  2023-01-01_L58  0
# 4  2023-01-01_UMC  0

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

for i, station in enumerate(stations):
    print(f"Training for station {station}, step {i+1}")
    df = df_per_station[station]
    X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
    y_train = df[df['train'] == 1]['y']
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

    rf = RandomForestRegressor(n_estimators=100, random_state=42)
    rf.fit(X_train[['job', 'ferie', 'vacances']], y_train)
    y_pred_val = rf.predict(X_val[['job', 'ferie', 'vacances']])
    print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

    y_pred = rf.predict(X_test[['job', 'ferie', 'vacances']])
    y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

y_test.to_csv('y_test_submit_rf_each_station_with_factors.csv')
# Out:
# Training for station 1J7, step 1
# MAPE for station 1J7 on validation set: 2393441.8040531892
# Training for station S3E, step 2
# MAPE for station S3E on validation set: 17306915.210617162
# Training for station RDK, step 3
# MAPE for station RDK on validation set: 7994884.694134495
# Training for station I9U, step 4
# MAPE for station I9U on validation set: 406.5487733767957
# Training for station OM7, step 5
# MAPE for station OM7 on validation set: 13501220.216280831
# Training for station 09U, step 6
# MAPE for station 09U on validation set: 3317549.9806084204
# Training for station 0S9, step 7
# MAPE for station 0S9 on validation set: 9337753.354812294
# Training for station KO0, step 8
# MAPE for station KO0 on validation set: 87.60922003275266
# Training for station 4WI, step 9
# MAPE for station 4WI on validation set: 290.77115002857454
# Training for station 23N, step 10
# MAPE for station 23N on validation set: 31688257.22984951
# Training for station WVV, step 11
# MAPE for station WVV on validation set: 24224374.389814872
# Training for station SWS, step 12
# MAPE for station SWS on validation set: 9776295.60658715
# Training for station TFW, step 13
# MAPE for station TFW on validation set: 8016094.468709679
# Training for station X3T, step 14
# MAPE for station X3T on validation set: 13141093.350402674
# Training for station I8D, step 15
# MAPE for station I8D on validation set: 33909907.42503001
# Training for station EOE, step 16
# MAPE for station EOE on validation set: 6329405.483917054
# Training for station MBC, step 17
# MAPE for station MBC on validation set: 223.79240825113902
# Training for station VS0, step 18
# MAPE for station VS0 on validation set: 4452415.236466576
# Training for station EVR, step 19
# MAPE for station EVR on validation set: 14544796.467401925
# Training for station BZL, step 20
# MAPE for station BZL on validation set: 22418147.176166933
# Training for station DF2, step 21
# MAPE for station DF2 on validation set: 1628626.201442205
# Training for station APM, step 22
# MAPE for station APM on validation set: 16863080.01398041
# Training for station 12Q, step 23
# MAPE for station 12Q on validation set: 3001298.680015983
# Training for station L6F, step 24
# MAPE for station L6F on validation set: 43309825.440993905
# Training for station WDP, step 25
# MAPE for station WDP on validation set: 3652472.6638390413
# Training for station ZII, step 26
# MAPE for station ZII on validation set: 103.22570743324118
# Training for station W67, step 27
# MAPE for station W67 on validation set: 39.05255883399732
# Training for station 4V8, step 28
# MAPE for station 4V8 on validation set: 20931382.06084813
# Training for station 214, step 29
# MAPE for station 214 on validation set: 178.58085864882005
# Training for station 2YA, step 30
# MAPE for station 2YA on validation set: 54.33770188048255
# Training for station L15, step 31
# MAPE for station L15 on validation set: 38528305.36158641
# Training for station PRZ, step 32
# MAPE for station PRZ on validation set: 18282890.644308962
# Training for station 2UV, step 33
# MAPE for station 2UV on validation set: 57.06201565589261
# Training for station OF0, step 34
# MAPE for station OF0 on validation set: 47737021.9983246
# Training for station PCE, step 35
# MAPE for station PCE on validation set: 36471846.75489662
# Training for station UAJ, step 36
# MAPE for station UAJ on validation set: 100278309.83053815
# Training for station K75, step 37
# MAPE for station K75 on validation set: 509.98418816661655
# Training for station 9RF, step 38
# MAPE for station 9RF on validation set: 508.15920760085965
# Training for station 2EW, step 39
# MAPE for station 2EW on validation set: 107.77689989922821
# Training for station 6E0, step 40
# MAPE for station 6E0 on validation set: 50.3222946520861
# Training for station 033, step 41
# MAPE for station 033 on validation set: 64723149.81725111
# Training for station KHT, step 42
# MAPE for station KHT on validation set: 294.0650348763978
# Training for station P8U, step 43
# MAPE for station P8U on validation set: 54255669.18926381
# Training for station CW1, step 44
# MAPE for station CW1 on validation set: 79.6792137025793
# Training for station AK3, step 45
# MAPE for station AK3 on validation set: 271.5736524431413
# Training for station IJR, step 46
# MAPE for station IJR on validation set: 137.22871376719775
# Training for station CM6, step 47
# MAPE for station CM6 on validation set: 88.44261476705546
# Training for station NZP, step 48
# MAPE for station NZP on validation set: 459.2202957903074
# Training for station ICH, step 49
# MAPE for station ICH on validation set: 114.65788789111578
# Training for station Q62, step 50
# MAPE for station Q62 on validation set: 551476863.258841
# Training for station 19G, step 51
# MAPE for station 19G on validation set: 213.2409997309283
# Training for station CS1, step 52
# MAPE for station CS1 on validation set: 10446852.737297852
# Training for station T2H, step 53
# MAPE for station T2H on validation set: 43.51176558702678
# Training for station TMT, step 54
# MAPE for station TMT on validation set: 881.4980233674765
# Training for station DRI, step 55
# MAPE for station DRI on validation set: 4118674.068055046
# Training for station KAX, step 56
# MAPE for station KAX on validation set: 6278195.370622191
# Training for station BC6, step 57
# MAPE for station BC6 on validation set: 597.4180468170558
# Training for station 6VM, step 58
# MAPE for station 6VM on validation set: 1066616.6282376389
# Training for station UCE, step 59
# MAPE for station UCE on validation set: 5856088.021698761
# Training for station 0CM, step 60
# MAPE for station 0CM on validation set: 7654403.388733926
# Training for station V5L, step 61
# MAPE for station V5L on validation set: 5246122.823965201
# Training for station BI7, step 62
# MAPE for station BI7 on validation set: 125.87599638033917
# Training for station Q5M, step 63
# MAPE for station Q5M on validation set: 4325672.47207926
# Training for station 1EB, step 64
# MAPE for station 1EB on validation set: 67.29509101691426
# Training for station IAM, step 65
# MAPE for station IAM on validation set: 33817251.65091048
# Training for station AOW, step 66
# MAPE for station AOW on validation set: 85.43648857467116
# Training for station YX9, step 67
# MAPE for station YX9 on validation set: 2989330.6494555236
# Training for station 7EJ, step 68
# MAPE for station 7EJ on validation set: 1952924.3019803227
# Training for station 0WC, step 69
# MAPE for station 0WC on validation set: 5166136.428424697
# Training for station WQR, step 70
# MAPE for station WQR on validation set: 2670695.141969944
# Training for station WQO, step 71
# MAPE for station WQO on validation set: 1604650.6501947385
# Training for station LHY, step 72
# MAPE for station LHY on validation set: 8444861.816028565
# Training for station 193, step 73
# MAPE for station 193 on validation set: 13228659.727696173
# Training for station PQF, step 74
# MAPE for station PQF on validation set: 7053180.34422544
# Training for station XN6, step 75
# MAPE for station XN6 on validation set: 4675964.416982643
# Training for station 0YY, step 76
# MAPE for station 0YY on validation set: 10553811.84048727
# Training for station 1VL, step 77
# MAPE for station 1VL on validation set: 8102188.168808313
# Training for station 1AA, step 78
# MAPE for station 1AA on validation set: 19279963.076967046
# Training for station A1R, step 79
# MAPE for station A1R on validation set: 39993635.26109613
# Training for station 9P6, step 80
# MAPE for station 9P6 on validation set: 74.04489334158527
# Training for station 6HE, step 81
# MAPE for station 6HE on validation set: 22581073.936581593
# Training for station 700, step 82
# MAPE for station 700 on validation set: 85572003.1285172
# Training for station SZ5, step 83
# MAPE for station SZ5 on validation set: 132.68558643065498
# Training for station H2M, step 84
# MAPE for station H2M on validation set: 5012140.05209902
# Training for station SSM, step 85
# MAPE for station SSM on validation set: 480.7368218001783
# Training for station G1F, step 86
# MAPE for station G1F on validation set: 449.1299366739211
# Training for station QTM, step 87
# MAPE for station QTM on validation set: 163973539.1632001
# Training for station K6N, step 88
# MAPE for station K6N on validation set: 94.6373554956757
# Training for station N6O, step 89
# MAPE for station N6O on validation set: 5087176.115131865
# Training for station HZ1, step 90
# MAPE for station HZ1 on validation set: 4789733.594966436
# Training for station ZIK, step 91
# MAPE for station ZIK on validation set: 309.13981925861344
# Training for station 294, step 92
# MAPE for station 294 on validation set: 172.17532828073027
# Training for station Y1C, step 93
# MAPE for station Y1C on validation set: 197246228.6033697
# Training for station BUH, step 94
# MAPE for station BUH on validation set: 106.25952099146276
# Training for station XM1, step 95
# MAPE for station XM1 on validation set: 155782108.38151148
# Training for station 0GU, step 96
# MAPE for station 0GU on validation set: 5435577.479963246
# Training for station B34, step 97
# MAPE for station B34 on validation set: 4359835.802856372
# Training for station NXN, step 98
# MAPE for station NXN on validation set: 15311584.958754795
# Training for station 9MC, step 99
# MAPE for station 9MC on validation set: 2765600.8356825123
# Training for station JFA, step 100
# MAPE for station JFA on validation set: 50136614.115734406
# Training for station AGN, step 101
# MAPE for station AGN on validation set: 135.26537479721128
# Training for station I6E, step 102
# MAPE for station I6E on validation set: 6981318.648757821
# Training for station W68, step 103
# MAPE for station W68 on validation set: 11414117.515305318
# Training for station VZD, step 104
# MAPE for station VZD on validation set: 5271412.245342923
# Training for station V6N, step 105
# MAPE for station V6N on validation set: 7409664.225561426
# Training for station 5SM, step 106
# MAPE for station 5SM on validation set: 248.53889387670483
# Training for station UM6, step 107
# MAPE for station UM6 on validation set: 65.65425134819692
# Training for station 4RW, step 108
# MAPE for station 4RW on validation set: 209.61071076138217
# Training for station MPO, step 109
# MAPE for station MPO on validation set: 37232177.59606049
# Training for station MX8, step 110
# MAPE for station MX8 on validation set: 910.7150933388772
# Training for station MBB, step 111
# MAPE for station MBB on validation set: 500.00213899784114
# Training for station FTX, step 112
# MAPE for station FTX on validation set: 103.28894968144124
# Training for station PD6, step 113
# MAPE for station PD6 on validation set: 845.1132058884507
# Training for station T16, step 114
# MAPE for station T16 on validation set: 78.89830634679514
# Training for station I10, step 115
# MAPE for station I10 on validation set: 42.42675312828224
# Training for station WNT, step 116
# MAPE for station WNT on validation set: 130.76194365123624
# Training for station 4EG, step 117
# MAPE for station 4EG on validation set: 72075132.15342744
# Training for station X2X, step 118
# MAPE for station X2X on validation set: 86749541.68818104
# Training for station HN1, step 119
# MAPE for station HN1 on validation set: 84.00414461991586
# Training for station ARC, step 120
# MAPE for station ARC on validation set: 96091203.81705455
# Training for station T5V, step 121
# MAPE for station T5V on validation set: 39.40489618897629
# Training for station K2M, step 122
# MAPE for station K2M on validation set: 223.19017798500553
# Training for station V2R, step 123
# MAPE for station V2R on validation set: 510965195.4183899
# Training for station OE1, step 124
# MAPE for station OE1 on validation set: 900.9916458517143
# Training for station 94K, step 125
# MAPE for station 94K on validation set: 583.1432249031129
# Training for station C5E, step 126
# MAPE for station C5E on validation set: 136.27183551789827
# Training for station VTE, step 127
# MAPE for station VTE on validation set: 168.16176206442844
# Training for station 2T1, step 128
# MAPE for station 2T1 on validation set: 669.4450561910362
# Training for station 0JU, step 129
# MAPE for station 0JU on validation set: 1003.080783070932
# Training for station X3Q, step 130
# MAPE for station X3Q on validation set: 458.7763713589987
# Training for station RVB, step 131
# MAPE for station RVB on validation set: 291.12477241402365
# Training for station 488, step 132
# MAPE for station 488 on validation set: 23639381.107473493
# Training for station DS2, step 133
# MAPE for station DS2 on validation set: 42469304.24531208
# Training for station 4CZ, step 134
# MAPE for station 4CZ on validation set: 338.15611236756007
# Training for station 9LN, step 135
# MAPE for station 9LN on validation set: 3312191.5874927714
# Training for station 6FB, step 136
# MAPE for station 6FB on validation set: 89.42089111815301
# Training for station XXI, step 137
# MAPE for station XXI on validation set: 35223118.82150132
# Training for station 959, step 138
# MAPE for station 959 on validation set: 953.8915630230262
# Training for station 2SG, step 139
# MAPE for station 2SG on validation set: 244618309.1175558
# Training for station CQT, step 140
# MAPE for station CQT on validation set: 887484580.167437
# Training for station B5A, step 141
# MAPE for station B5A on validation set: 296740428.14693636
# Training for station YAQ, step 142
# MAPE for station YAQ on validation set: 163269662.60447752
# Training for station RPX, step 143
# MAPE for station RPX on validation set: 358.99845250272244
# Training for station VTP, step 144
# MAPE for station VTP on validation set: 124453736.5952192
# Training for station 4MO, step 145
# MAPE for station 4MO on validation set: 33349977.26228802
# Training for station 034, step 146
# MAPE for station 034 on validation set: 157248336.16076866
# Training for station BJ5, step 147
# MAPE for station BJ5 on validation set: 14592160.56139526
# Training for station KBV, step 148
# MAPE for station KBV on validation set: 147.27994696971996
# Training for station J52, step 149
# MAPE for station J52 on validation set: 318.50617324574876
# Training for station 2AC, step 150
# MAPE for station 2AC on validation set: 1653.0197627632685
# Training for station 56W, step 151
# MAPE for station 56W on validation set: 567510247.2987041
# Training for station T29, step 152
# MAPE for station T29 on validation set: 59591881.0252398
# Training for station PEA, step 153
# MAPE for station PEA on validation set: 25851614.75256374
# Training for station BL1, step 154
# MAPE for station BL1 on validation set: 370.0042348820366
# Training for station YJK, step 155
# MAPE for station YJK on validation set: 11167529.896823902
# Training for station 92P, step 156
# MAPE for station 92P on validation set: 23615080.385985933
# Training for station NEG, step 157
# MAPE for station NEG on validation set: 166.62113151879643
# Training for station 3T2, step 158
# MAPE for station 3T2 on validation set: 27753082.746558607
# Training for station N6I, step 159
# MAPE for station N6I on validation set: 269486027.5319192
# Training for station QL3, step 160
# MAPE for station QL3 on validation set: 39716409.20517284
# Training for station M36, step 161
# MAPE for station M36 on validation set: 12572.35593690568
# Training for station X6B, step 162
# MAPE for station X6B on validation set: 270666744.68305516
# Training for station O5P, step 163
# MAPE for station O5P on validation set: 929.7591266988607
# Training for station CET, step 164
# MAPE for station CET on validation set: 2416.726090846523
# Training for station E6L, step 165
# MAPE for station E6L on validation set: 357.5543155082936
# Training for station P7I, step 166
# MAPE for station P7I on validation set: 46052624.07860651
# Training for station 9IV, step 167
# MAPE for station 9IV on validation set: 90321977.56636979
# Training for station 0ZP, step 168
# MAPE for station 0ZP on validation set: 48582171.06633717
# Training for station 52H, step 169
# MAPE for station 52H on validation set: 663262223.2974033
# Training for station PWO, step 170
# MAPE for station PWO on validation set: 19983585.22077709
# Training for station 6TL, step 171
# MAPE for station 6TL on validation set: 151.9012103585083
# Training for station X95, step 172
# MAPE for station X95 on validation set: 35440201.25555479
# Training for station NSN, step 173
# MAPE for station NSN on validation set: 1068.8736238058182
# Training for station GIE, step 174
# MAPE for station GIE on validation set: 48322620.04939861
# Training for station IJC, step 175
# MAPE for station IJC on validation set: 665.1367819137206
# Training for station BJM, step 176
# MAPE for station BJM on validation set: 525.1009632421309
# Training for station TV1, step 177
# MAPE for station TV1 on validation set: 170861330.1239308
# Training for station AZV, step 178
# MAPE for station AZV on validation set: 188933449.12018153
# Training for station TCL, step 179
# MAPE for station TCL on validation set: 72674163.76272939
# Training for station VEO, step 180
# MAPE for station VEO on validation set: 283.2136410899087
# Training for station WO7, step 181
# MAPE for station WO7 on validation set: 84.237397262583
# Training for station WMZ, step 182
# MAPE for station WMZ on validation set: 99.76373599742008
# Training for station 3Y4, step 183
# MAPE for station 3Y4 on validation set: 26077946.54357052
# Training for station OQD, step 184
# MAPE for station OQD on validation set: 87730588.36687833
# Training for station UC4, step 185
# MAPE for station UC4 on validation set: 249.62938834837502
# Training for station GMD, step 186
# MAPE for station GMD on validation set: 680.6929404785301
# Training for station Z76, step 187
# MAPE for station Z76 on validation set: 237609568.576608
# Training for station VBL, step 188
# MAPE for station VBL on validation set: 640.5744628104557
# Training for station VMM, step 189
# MAPE for station VMM on validation set: 283649687.7875993
# Training for station BE1, step 190
# MAPE for station BE1 on validation set: 991.8484085758587
# Training for station TGW, step 191
# MAPE for station TGW on validation set: 38655733.545540385
# Training for station W06, step 192
# MAPE for station W06 on validation set: 98993945.86963454
# Training for station GUQ, step 193
# MAPE for station GUQ on validation set: 354.08177769754445
# Training for station ANI, step 194
# MAPE for station ANI on validation set: 123.77448958828099
# Training for station TO8, step 195
# MAPE for station TO8 on validation set: 12174801.239756923
# Training for station I7J, step 196
# MAPE for station I7J on validation set: 140.74285709645866
# Training for station 26J, step 197
# MAPE for station 26J on validation set: 1466.2904407704611
# Training for station REW, step 198
# MAPE for station REW on validation set: 569.1669644726321
# Training for station K4X, step 199
# MAPE for station K4X on validation set: 260.5433333318839
# Training for station XL2, step 200
# MAPE for station XL2 on validation set: 302.774057519707
# Training for station H2L, step 201
# MAPE for station H2L on validation set: 678.4049008598331
# Training for station I8O, step 202
# MAPE for station I8O on validation set: 126.99294421682691
# Training for station HXV, step 203
# MAPE for station HXV on validation set: 197808072.89462674
# Training for station ESA, step 204
# MAPE for station ESA on validation set: 969.9343671725276
# Training for station 8XN, step 205
# MAPE for station 8XN on validation set: 46.91263832449082
# Training for station 4AH, step 206
# MAPE for station 4AH on validation set: 32317245.757526033
# Training for station ZSR, step 207
# MAPE for station ZSR on validation set: 97572819.7349978
# Training for station KEC, step 208
# MAPE for station KEC on validation set: 198290955.78831
# Training for station PUW, step 209
# MAPE for station PUW on validation set: 66896151.04731632
# Training for station 0TR, step 210
# MAPE for station 0TR on validation set: 310.81549566861753
# Training for station B8A, step 211
# MAPE for station B8A on validation set: 14684207.509826155
# Training for station KY2, step 212
# MAPE for station KY2 on validation set: 10718199.841829572
# Training for station Q70, step 213
# MAPE for station Q70 on validation set: 269290699.3925093
# Training for station 4YU, step 214
# MAPE for station 4YU on validation set: 7514831.312509947
# Training for station N7J, step 215
# MAPE for station N7J on validation set: 338.19343140126216
# Training for station 9WY, step 216
# MAPE for station 9WY on validation set: 74.74818463846594
# Training for station HOX, step 217
# MAPE for station HOX on validation set: 6532305.128334234
# Training for station B3W, step 218
# MAPE for station B3W on validation set: 11136881.621722814
# Training for station VGQ, step 219
# MAPE for station VGQ on validation set: 209.2622347009433
# Training for station BNR, step 220
# MAPE for station BNR on validation set: 1236829.4484360444
# Training for station 3KU, step 221
# MAPE for station 3KU on validation set: 257.74053946947834
# Training for station V4D, step 222
# MAPE for station V4D on validation set: 8290430.175284743
# Training for station EBP, step 223
# MAPE for station EBP on validation set: 5172335.216713304
# Training for station JD3, step 224
# MAPE for station JD3 on validation set: 227.6603649589049
# Training for station 34L, step 225
# MAPE for station 34L on validation set: 3815686.597684556
# Training for station MK9, step 226
# MAPE for station MK9 on validation set: 13473656.317061529
# Training for station 5S5, step 227
# MAPE for station 5S5 on validation set: 9676621.595220996
# Training for station BZ0, step 228
# MAPE for station BZ0 on validation set: 8805032.74687446
# Training for station 59A, step 229
# MAPE for station 59A on validation set: 3625069.4746695785
# Training for station 4IM, step 230
# MAPE for station 4IM on validation set: 9385726.075193921
# Training for station CWQ, step 231
# MAPE for station CWQ on validation set: 18378537.301617302
# Training for station 30I, step 232
# MAPE for station 30I on validation set: 7127146.543869066
# Training for station HW6, step 233
# MAPE for station HW6 on validation set: 14408336.748344786
# Training for station JX6, step 234
# MAPE for station JX6 on validation set: 338.0518107403918
# Training for station F77, step 235
# MAPE for station F77 on validation set: 3487198.21493621
# Training for station JCW, step 236
# MAPE for station JCW on validation set: 119222051.60710518
# Training for station FBH, step 237
# MAPE for station FBH on validation set: 25172564.40601013
# Training for station P4J, step 238
# MAPE for station P4J on validation set: 215.98460162109583
# Training for station QV8, step 239
# MAPE for station QV8 on validation set: 6880816.859723913
# Training for station J9O, step 240
# MAPE for station J9O on validation set: 56.524358537152374
# Training for station 5WG, step 241
# MAPE for station 5WG on validation set: 7925749.508548192
# Training for station 5PK, step 242
# MAPE for station 5PK on validation set: 251.4521877685286
# Training for station 4PO, step 243
# MAPE for station 4PO on validation set: 436881773.92442685
# Training for station 72S, step 244
# MAPE for station 72S on validation set: 80.99098806992934
# Training for station XOK, step 245
# MAPE for station XOK on validation set: 16830342.87781752
# Training for station GKH, step 246
# MAPE for station GKH on validation set: 38336396.43221891
# Training for station BPW, step 247
# MAPE for station BPW on validation set: 23325525.046856202
# Training for station 5U5, step 248
# MAPE for station 5U5 on validation set: 394.0874480922301
# Training for station CJP, step 249
# MAPE for station CJP on validation set: 74.40552442270165
# Training for station NVE, step 250
# MAPE for station NVE on validation set: 179.17118753187518
# Training for station T91, step 251
# MAPE for station T91 on validation set: 78.57368788421165
# Training for station BKJ, step 252
# MAPE for station BKJ on validation set: 233.33559266797218
# Training for station XRB, step 253
# MAPE for station XRB on validation set: 25678052.495083977
# Training for station 289, step 254
# MAPE for station 289 on validation set: 17387578.39666442
# Training for station 87K, step 255
# MAPE for station 87K on validation set: 5182043.523307414
# Training for station EIZ, step 256
# MAPE for station EIZ on validation set: 25561487.08679853
# Training for station 3W6, step 257
# MAPE for station 3W6 on validation set: 337.6253005978303
# Training for station HOC, step 258
# MAPE for station HOC on validation set: 100.14611179640728
# Training for station 651, step 259
# MAPE for station 651 on validation set: 196.94282661107
# Training for station 3NQ, step 260
# MAPE for station 3NQ on validation set: 11889799.142787093
# Training for station DBV, step 261
# MAPE for station DBV on validation set: 12004008.976240426
# Training for station SH9, step 262
# MAPE for station SH9 on validation set: 177531287.19170812
# Training for station QQJ, step 263
# MAPE for station QQJ on validation set: 12221319.68135863
# Training for station 5GK, step 264
# MAPE for station 5GK on validation set: 3805442.0367141645
# Training for station FYB, step 265
# MAPE for station FYB on validation set: 34057736.231424876
# Training for station 8WZ, step 266
# MAPE for station 8WZ on validation set: 7168509.547029247
# Training for station 6WR, step 267
# MAPE for station 6WR on validation set: 1860169.8880728455
# Training for station 5KB, step 268
# MAPE for station 5KB on validation set: 3523569.6090495293
# Training for station MNO, step 269
# MAPE for station MNO on validation set: 9359534.13011022
# Training for station GV0, step 270
# MAPE for station GV0 on validation set: 4369289.8757260265
# Training for station VML, step 271
# MAPE for station VML on validation set: 864530.0824184369
# Training for station EPD, step 272
# MAPE for station EPD on validation set: 203.45590954060907
# Training for station FA8, step 273
# MAPE for station FA8 on validation set: 2283081.906924969
# Training for station I9K, step 274
# MAPE for station I9K on validation set: 13073544.227563351
# Training for station 4UY, step 275
# MAPE for station 4UY on validation set: 5743022.529539472
# Training for station CUF, step 276
# MAPE for station CUF on validation set: 295.67207463517224
# Training for station TEP, step 277
# MAPE for station TEP on validation set: 11963120.807674147
# Training for station RYX, step 278
# MAPE for station RYX on validation set: 2132343.577251746
# Training for station O7B, step 279
# MAPE for station O7B on validation set: 7620449.927642448
# Training for station 357, step 280
# MAPE for station 357 on validation set: 1092657.3355071945
# Training for station EK4, step 281
# MAPE for station EK4 on validation set: 2978930.50053204
# Training for station V8D, step 282
# MAPE for station V8D on validation set: 1819226.5420303938
# Training for station KY6, step 283
# MAPE for station KY6 on validation set: 242.8430831994343
# Training for station I1K, step 284
# MAPE for station I1K on validation set: 71.08464082821924
# Training for station FK3, step 285
# MAPE for station FK3 on validation set: 10633337.363207486
# Training for station UMC, step 286
# MAPE for station UMC on validation set: 2247929.742716834
# Training for station 8QR, step 287
# MAPE for station 8QR on validation set: 2683248.4737703744
# Training for station O2O, step 288
# MAPE for station O2O on validation set: 6508287.131486399
# Training for station VVQ, step 289
# MAPE for station VVQ on validation set: 154771879.34570283
# Training for station BRZ, step 290
# MAPE for station BRZ on validation set: 6923425.206637628
# Training for station 6DU, step 291
# MAPE for station 6DU on validation set: 4382964.876433548
# Training for station BUY, step 292
# MAPE for station BUY on validation set: 5285515.6171861
# Training for station 276, step 293
# MAPE for station 276 on validation set: 9639723.191391414
# Training for station VI4, step 294
# MAPE for station VI4 on validation set: 84.51390936696855
# Training for station J9C, step 295
# MAPE for station J9C on validation set: 7252860.4780080905
# Training for station IOR, step 296
# MAPE for station IOR on validation set: 6928711.530688664
# Training for station NT4, step 297
# MAPE for station NT4 on validation set: 115.8376563790394
# Training for station MM6, step 298
# MAPE for station MM6 on validation set: 3389216.349839014
# Training for station G10, step 299
# MAPE for station G10 on validation set: 12600593.009332323
# Training for station JCN, step 300
# MAPE for station JCN on validation set: 483.3490994893067
# Training for station OOY, step 301
# MAPE for station OOY on validation set: 6305743.339781426
# Training for station 30R, step 302
# MAPE for station 30R on validation set: 112.27538350222667
# Training for station CSD, step 303
# MAPE for station CSD on validation set: 27780927.163286142
# Training for station XIG, step 304
# MAPE for station XIG on validation set: 13828844.647170532
# Training for station R83, step 305
# MAPE for station R83 on validation set: 417.9028192170978
# Training for station 8X9, step 306
# MAPE for station 8X9 on validation set: 247.2233696024432
# Training for station GOJ, step 307
# MAPE for station GOJ on validation set: 132047063.44100969
# Training for station Z2T, step 308
# MAPE for station Z2T on validation set: 340.3778709047161
# Training for station YTV, step 309
# MAPE for station YTV on validation set: 148.87244662739758
# Training for station OD3, step 310
# MAPE for station OD3 on validation set: 41867742.71539185
# Training for station JXV, step 311
# MAPE for station JXV on validation set: 79.11032343015842
# Training for station XTG, step 312
# MAPE for station XTG on validation set: 91605052.01132487
# Training for station RR1, step 313
# MAPE for station RR1 on validation set: 161.28770007750967
# Training for station 6UW, step 314
# MAPE for station 6UW on validation set: 128.53655110962677
# Training for station 1PW, step 315
# MAPE for station 1PW on validation set: 387.8273031998518
# Training for station IFB, step 316
# MAPE for station IFB on validation set: 13886266.828279229
# Training for station C3A, step 317
# MAPE for station C3A on validation set: 2012642.0913643332
# Training for station MIH, step 318
# MAPE for station MIH on validation set: 722.7608995131816
# Training for station E9M, step 319
# MAPE for station E9M on validation set: 15415230.159753384
# Training for station DSX, step 320
# MAPE for station DSX on validation set: 2586988.1450511646
# Training for station XKD, step 321
# MAPE for station XKD on validation set: 250.62300654618156
# Training for station W7F, step 322
# MAPE for station W7F on validation set: 1009.5992386376591
# Training for station 45E, step 323
# MAPE for station 45E on validation set: 65.25846471016209
# Training for station BHE, step 324
# MAPE for station BHE on validation set: 104.01703643854118
# Training for station A8Q, step 325
# MAPE for station A8Q on validation set: 103.42335497920949
# Training for station DMX, step 326
# MAPE for station DMX on validation set: 8700994.531596836
# Training for station B45, step 327
# MAPE for station B45 on validation set: 17744446.696048796
# Training for station 0Y9, step 328
# MAPE for station 0Y9 on validation set: 2984030.687970658
# Training for station 182, step 329
# MAPE for station 182 on validation set: 121.39363023251124
# Training for station SAD, step 330
# MAPE for station SAD on validation set: 16587839.426887605
# Training for station TVC, step 331
# MAPE for station TVC on validation set: 767356619.5895001
# Training for station 1EX, step 332
# MAPE for station 1EX on validation set: 513.2945074649308
# Training for station FKG, step 333
# MAPE for station FKG on validation set: 79.50431466102648
# Training for station 856, step 334
# MAPE for station 856 on validation set: 220.68197154214525
# Training for station Y5A, step 335
# MAPE for station Y5A on validation set: 188835977.18411243
# Training for station KN2, step 336
# MAPE for station KN2 on validation set: 4464231.583768258
# Training for station J4R, step 337
# MAPE for station J4R on validation set: 323.3125839572915
# Training for station YLE, step 338
# MAPE for station YLE on validation set: 12795569.586919658
# Training for station BRP, step 339
# MAPE for station BRP on validation set: 1669.3878473176592
# Training for station SYW, step 340
# MAPE for station SYW on validation set: 13532134.024010614
# Training for station 003, step 341
# MAPE for station 003 on validation set: 11698979.978290036
# Training for station EMR, step 342
# MAPE for station EMR on validation set: 179.98658163447178
# Training for station VA1, step 343
# MAPE for station VA1 on validation set: 11186711.791992832
# Training for station FSR, step 344
# MAPE for station FSR on validation set: 14466281.291090924
# Training for station ZXY, step 345
# MAPE for station ZXY on validation set: 273.52173179484237
# Training for station 3XF, step 346
# MAPE for station 3XF on validation set: 364.7184137341168
# Training for station H5M, step 347
# MAPE for station H5M on validation set: 52619030.97430064
# Training for station 6A9, step 348
# MAPE for station 6A9 on validation set: 2105024.7617490715
# Training for station 969, step 349
# MAPE for station 969 on validation set: 3645622.1528459517
# Training for station TGR, step 350
# MAPE for station TGR on validation set: 104.5788034716262
# Training for station NWM, step 351
# MAPE for station NWM on validation set: 71.89833425347003
# Training for station PBR, step 352
# MAPE for station PBR on validation set: 173502324.90839705
# Training for station RM4, step 353
# MAPE for station RM4 on validation set: 5426515.732959634
# Training for station AOH, step 354
# MAPE for station AOH on validation set: 25567475.110132016
# Training for station 8PU, step 355
# MAPE for station 8PU on validation set: 25890461.172314566
# Training for station GTH, step 356
# MAPE for station GTH on validation set: 27198585.59606927
# Training for station R2F, step 357
# MAPE for station R2F on validation set: 13698657.490317859
# Training for station TXU, step 358
# MAPE for station TXU on validation set: 39625819.842084736
# Training for station WDG, step 359
# MAPE for station WDG on validation set: 157.89459138668227
# Training for station C4L, step 360
# MAPE for station C4L on validation set: 7025880.335902641
# Training for station MDL, step 361
# MAPE for station MDL on validation set: 159.67736112675848
# Training for station KA0, step 362
# MAPE for station KA0 on validation set: 81.90083317303873
# Training for station VTD, step 363
# MAPE for station VTD on validation set: 65.271904689933
# Training for station EHY, step 364
# MAPE for station EHY on validation set: 56584090.784813985
# Training for station 43B, step 365
# MAPE for station 43B on validation set: 58.99138740837414
# Training for station HID, step 366
# MAPE for station HID on validation set: 263.4418532284455
# Training for station 495, step 367
# MAPE for station 495 on validation set: 1957748.6632902382
# Training for station 47F, step 368
# MAPE for station 47F on validation set: 3022169.4611373134
# Training for station VEF, step 369
# MAPE for station VEF on validation set: 6691590.450007282
# Training for station 5KJ, step 370
# MAPE for station 5KJ on validation set: 206497347.2582248
# Training for station YDH, step 371
# MAPE for station YDH on validation set: 77.38479622191011
# Training for station 9IN, step 372
# MAPE for station 9IN on validation set: 255504562.79755634
# Training for station Z1H, step 373
# MAPE for station Z1H on validation set: 687.546012196543
# Training for station OUG, step 374
# MAPE for station OUG on validation set: 17963442.867115628
# Training for station F30, step 375
# MAPE for station F30 on validation set: 42157225.708800025
# Training for station TPX, step 376
# MAPE for station TPX on validation set: 17628154.02310445
# Training for station WIX, step 377
# MAPE for station WIX on validation set: 138889427.26319003
# Training for station 56P, step 378
# MAPE for station 56P on validation set: 167.83717480302954
# Training for station Z5T, step 379
# MAPE for station Z5T on validation set: 880038.5824672052
# Training for station XUL, step 380
# MAPE for station XUL on validation set: 74.86003430554771
# Training for station 25G, step 381
# MAPE for station 25G on validation set: 228.9080910346541
# Training for station OTS, step 382
# MAPE for station OTS on validation set: 122.99811806006542
# Training for station 3NS, step 383
# MAPE for station 3NS on validation set: 85.30418936674457
# Training for station 4SH, step 384
# MAPE for station 4SH on validation set: 135587106.55618048
# Training for station 11W, step 385
# MAPE for station 11W on validation set: 86.35957344562696
# Training for station GN3, step 386
# MAPE for station GN3 on validation set: 26801926.14580802
# Training for station CYD, step 387
# MAPE for station CYD on validation set: 375.5562682646159
# Training for station 1TE, step 388
# MAPE for station 1TE on validation set: 84.93861711241196
# Training for station 222, step 389
# MAPE for station 222 on validation set: 21810270.47876224
# Training for station 7NG, step 390
# MAPE for station 7NG on validation set: 143.85584093270734
# Training for station 8E0, step 391
# MAPE for station 8E0 on validation set: 18852639.29316717
# Training for station B61, step 392
# MAPE for station B61 on validation set: 1226.8148383851606
# Training for station B3D, step 393
# MAPE for station B3D on validation set: 165.2005780549007
# Training for station P3G, step 394
# MAPE for station P3G on validation set: 31185534.836234815
# Training for station OYD, step 395
# MAPE for station OYD on validation set: 2963908.45732663
# Training for station KDO, step 396
# MAPE for station KDO on validation set: 24047334.48357833
# Training for station APN, step 397
# MAPE for station APN on validation set: 2108018.6066977116
# Training for station WRR, step 398
# MAPE for station WRR on validation set: 10792147.4726464
# Training for station F7I, step 399
# MAPE for station F7I on validation set: 8229795.734206426
# Training for station D68, step 400
# MAPE for station D68 on validation set: 26124143.199142165
# Training for station K5Q, step 401
# MAPE for station K5Q on validation set: 19556971.325638473
# Training for station WGP, step 402
# MAPE for station WGP on validation set: 50702550.6115504
# Training for station K71, step 403
# MAPE for station K71 on validation set: 72.936048435804
# Training for station FBN, step 404
# MAPE for station FBN on validation set: 19311004.43735021
# Training for station 745, step 405
# MAPE for station 745 on validation set: 66720924.34874929
# Training for station 1TQ, step 406
# MAPE for station 1TQ on validation set: 5094238.260097516
# Training for station VAU, step 407
# MAPE for station VAU on validation set: 409.40769869767735
# Training for station 5MR, step 408
# MAPE for station 5MR on validation set: 274449.26599199267
# Training for station 5ZC, step 409
# MAPE for station 5ZC on validation set: 344564012.8503535
# Training for station CRS, step 410
# MAPE for station CRS on validation set: 120.65154209012906
# Training for station Z4A, step 411
# MAPE for station Z4A on validation set: 3575894.834715504
# Training for station 18L, step 412
# MAPE for station 18L on validation set: 218544871.68027973
# Training for station 2PZ, step 413
# MAPE for station 2PZ on validation set: 87262342.00436608
# Training for station JP8, step 414
# MAPE for station JP8 on validation set: 1067.449153974319
# Training for station 1I8, step 415
# MAPE for station 1I8 on validation set: 3784406.273761251
# Training for station 2P1, step 416
# MAPE for station 2P1 on validation set: 104210749.75596212
# Training for station B9M, step 417
# MAPE for station B9M on validation set: 53097356.431237385
# Training for station H1M, step 418
# MAPE for station H1M on validation set: 78.0931289145221
# Training for station 1EJ, step 419
# MAPE for station 1EJ on validation set: 68.13248935026331
# Training for station ROF, step 420
# MAPE for station ROF on validation set: 1018839.7607029439
# Training for station EFN, step 421
# MAPE for station EFN on validation set: 14853639.734071948
# Training for station B65, step 422
# MAPE for station B65 on validation set: 20062243.66802883
# Training for station KQC, step 423
# MAPE for station KQC on validation set: 451.24223443997886
# Training for station VV4, step 424
# MAPE for station VV4 on validation set: 13079410.219918802
# Training for station NZV, step 425
# MAPE for station NZV on validation set: 5696771.967130245
# Training for station L58, step 426
# MAPE for station L58 on validation set: 6851815.929149342
# Training for station EQX, step 427
# MAPE for station EQX on validation set: 36322007.22989585
# Training for station NEB, step 428
# MAPE for station NEB on validation set: 6129845.355570547
# Training for station RF2, step 429
# MAPE for station RF2 on validation set: 181.95080658289623
# Training for station GW7, step 430
# MAPE for station GW7 on validation set: 1041.8049845681269
# Training for station OWM, step 431
# MAPE for station OWM on validation set: 54.42876439970912
# Training for station V2P, step 432
# MAPE for station V2P on validation set: 243.46471660896643
# Training for station N9K, step 433
# MAPE for station N9K on validation set: 294.25780451715787
# Training for station 48S, step 434
# MAPE for station 48S on validation set: 687.4171712653815
# Training for station P6E, step 435
# MAPE for station P6E on validation set: 33.00080289639749
# Training for station BDC, step 436
# MAPE for station BDC on validation set: 26.99119223873261
# Training for station W14, step 437
# MAPE for station W14 on validation set: 532.0512707555574
# Training for station W80, step 438
# MAPE for station W80 on validation set: 48.45747987493849
# Training for station QD6, step 439
# MAPE for station QD6 on validation set: 27.291493458726197

# %% [markdown]
# # Bagging regressor (does not improve)

# %%
# from sklearn.ensemble import BaggingRegressor
# from sklearn.svm import SVR
# from sklearn.neighbors import KNeighborsRegressor as KNN

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     br = BaggingRegressor(KNN(), n_estimators=10, random_state=42)
#     br.fit(X_train[['job', 'ferie', 'vacances']], y_train)
#     y_pred_val = br.predict(X_val[['job', 'ferie', 'vacances']])
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     y_pred = br.predict(X_test[['job', 'ferie', 'vacances']])
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

# y_test.to_csv('y_test_submit_bagging_rf_each_station.csv')

# %% [markdown]
# # AdaBoost

# %%
# # Adaboost

# from sklearn.ensemble import AdaBoostRegressor

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     ab = AdaBoostRegressor(n_estimators=100, random_state=42)
#     ab.fit(X_train[['job', 'ferie', 'vacances']], y_train)
#     y_pred_val = ab.predict(X_val[['job', 'ferie', 'vacances']])
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     y_pred = ab.predict(X_test[['job', 'ferie', 'vacances']])
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

# y_test.to_csv('y_test_submit_adaboost_each_station.csv')

# %% [markdown]
# # Gradient boosting

# %%
# # gradient boosting

# from sklearn.ensemble import GradientBoostingRegressor

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     gb = GradientBoostingRegressor(n_estimators=100, random_state=42)
#     gb.fit(X_train[['job', 'ferie', 'vacances']], y_train)
#     y_pred_val = gb.predict(X_val[['job', 'ferie', 'vacances']])
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     y_pred = gb.predict(X_test[['job', 'ferie', 'vacances']])
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

# y_test.to_csv('y_test_submit_gb_each_station.csv')

# %% [markdown]
# # Linear regression

# %%
# # linear regression

# from sklearn.linear_model import LinearRegression

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     lr = LinearRegression()
#     lr.fit(X_train[['job', 'ferie', 'vacances']], y_train)
#     y_pred_val = lr.predict(X_val[['job', 'ferie', 'vacances']])
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     y_pred = lr.predict(X_test[['job', 'ferie', 'vacances']])
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

# y_test.to_csv('y_test_submit_lr_each_station.csv')

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, train_test_split
import matplotlib.pyplot as plt

idx = 1
for name_station in df_per_station.keys():
    print(f"Station {name_station}")
    idx += 1
    name_station = '1J7'
    
    X_train_station = df_per_station[str(name_station)][['job', 'ferie', 'vacances', 'day_of_week_cos', 'day_of_week_sin', 'day_of_year', 'day_of_month', 'day_of_week']]
    y_train_station = df_per_station[str(name_station)]['y']
    print(type(X_train_station))
    print(type(y_train_station))
    
    X_train_station_np = X_train_station.values
    y_train_station_np = y_train_station.values
    
    print(X_train_station_np.shape)
    print(y_train_station_np.shape)
    
    # Splitting the station-specific data for training and validation
    X_train_run, X_val_run, y_train_run, y_val_run = train_test_split(
        X_train_station_np, y_train_station_np, test_size=0.2, shuffle=False)
    
    # Set up Time Series Cross-Validation
    tscv = TimeSeriesSplit(n_splits=31)
    
    # Parameter grid for ElasticNet
    param_grid = {
        'alpha': [0.01, 0.1, 1, 10],
        'l1_ratio': [0.1, 0.5, 0.9, 1.5],
        'max_iter':[10000, 100000, 1000000],
        'tol': [0.01, 0.05, 0.10, 0.20, 0.001, 0.0001]
    }
    
    # Initialize ElasticNet with fixed parameters not being tuned
    model = ElasticNet()
    
    # GridSearchCV setup
    grid_search = GridSearchCV(
        model, param_grid, cv=tscv,
        scoring='neg_mean_absolute_percentage_error', verbose=1
    )
    
    # Fit GridSearchCV
    grid_search.fit(X_train_run, y_train_run)
    
    # Best model from grid search
    best_model = grid_search.best_estimator_
    
    # Prediction using the best model
    y_pred = best_model.predict(X_val_run)
    y_pred = np.where(y_pred < 0, 0, y_pred)
    # Evaluation
    score = mean_absolute_percentage_error(y_val_run, y_pred*1.15)
    print(f"MAPE Score: {score}")
    
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(y_val_run[:14], label='Actual Values', color='blue')
    plt.plot(y_pred[:14], label='Predicted Values', color='red', linestyle='--')
    plt.title(f'Actual vs Predicted Values for Station {idx-1}')
    plt.xlabel('Data Point Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

    break  # Remove this to process all stations

# %% [markdown]
# # XGBoost

# %%
# # XGBoost

# import xgboost as xgb

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
#                 max_depth = 5, alpha = 10, n_estimators = 100)
#     xg_reg.fit(X_train[['job', 'ferie', 'vacances']], y_train)
#     y_pred_val = xg_reg.predict(X_val[['job', 'ferie', 'vacances']])
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     y_pred = xg_reg.predict(X_test[['job', 'ferie', 'vacances']])
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

# y_test.to_csv('y_test_submit_xgb_each_station.csv')

# %% [markdown]
# # LightGBM

# %%
# # LightGBM

# import lightgbm as lgb

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     lgb_reg = lgb.LGBMRegressor(objective='regression', num_leaves=64, learning_rate=0.05, n_estimators=100)
#     lgb_reg.fit(X_train[['job', 'ferie', 'vacances']], y_train)
#     y_pred_val = lgb_reg.predict(X_val[['job', 'ferie', 'vacances']])
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     y_pred = lgb_reg.predict(X_test[['job', 'ferie', 'vacances']])
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = y_pred

# y_test.to_csv('y_test_submit_lgb_each_station_2.csv')

# %% [markdown]
# # SARIMAX

# %%
# # SARIMA

# # import datetime
# from datetime import datetime

# from statsmodels.tsa.statespace.sarimax import SARIMAX

# for i, station in enumerate(stations):
#     print(f"Training for station {station}, step {i+1}")
#     df = df_per_station[station]
#     X_train = df[df['train'] == 1][['date', 'job', 'ferie', 'vacances']]
#     y_train = df[df['train'] == 1]['y']
#     X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)
#     X_test = df[df['train'] == 0][['date', 'job', 'ferie', 'vacances']]

#     sarima = SARIMAX(y_train, X_train[["job", "ferie", "vacances"]].to_numpy(), order=(1, 1, 1), seasonal_order=(1, 1, 1, 12)).fit()
#     y_pred_val = sarima.get_forecast(steps=len(X_val), exog=X_val[["job", "ferie", "vacances"]].to_numpy()).predicted_mean
#     print(f"MAPE for station {station} on validation set: {mean_absolute_percentage_error(y_val, y_pred_val)}")

#     #y_pred = sarima.get_forecast(steps=len(X_test), exog=X_test[["job", "ferie", "vacances"]].to_numpy())
#     y_test.loc[y_test['index'].str.contains(station), 'y'] = list(sarima.get_forecast(steps=len(X_test), exog=X_test[["job", "ferie", "vacances"]].to_numpy()).predicted_mean)
#     #print(y_pred.predicted_mean)

# y_test['y'] = y_test['y'].abs()
# y_test.to_csv('y_test_submit_sarima_each_station.csv')
